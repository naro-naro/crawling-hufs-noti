# %% [markdown]
# # 구글 드라이브 마운트

# %%
# 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Okt 사용자 사전

# %%
#현재 경로. 보통 ./content일거에요!
import os
os.getcwd()
# Out:
# '/content'

# %%
#konlpy 다운 및 호출
#1. Konlpy에서 Okt
# !pip install konlpy
#2. konlpy 실행을 위한 자바어쩌구 다운
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
#3. 필요한 설정
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 33.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 40.1 MB/s eta 0:00:00
# ...

# %%
from konlpy.tag import Okt

# %%
okt = Okt()
# 한국외국어대학교 쪼개진거 확인.
# 처음: ['한국', '외국어', '대학교', '에서', '안', '내', '드리다', '.', '한', '국외', '대', '에서도', '안', '내', '하다', '.', '학식', '이', '쌀국수', '이다', '.']
# 개선 후: ['한국외국어대학교', '에서', '안', '내', '드리다', '.', '한국외대', '에서도', '안', '내', '하다', '.', '학식', '이', '쌀국수', '이다', '.']
print(okt.morphs("한국외국어대학교에서 안내드립니다. 한국외대에서도 안내합니다.학식이 쌀국수 입니다.", stem = True))
# Out:
# ['한국', '외국어', '대학교', '에서', '안', '내', '드리다', '.', '한', '국외', '대', '에서도', '안', '내', '하다', '.', '학식', '이', '쌀국수', '이다', '.']

# %%
# 사용자 사전 찾아가기 및 경로 설정 _ 여기서 오류가 날 시 코랩에서 폴더 열어서 usr,local 찾아가보시며 폴더명이 일치하는지 확인해보세요! 보통 파이썬 버전이 다릅니다.
os.chdir('/usr/local/lib/python3.10/dist-packages/konlpy/java')
os.getcwd()
# Out:
# '/usr/local/lib/python3.10/dist-packages/konlpy/java'

# %%
#jar파일을 풀어줄 폴더이름을 정합니다. 저는 temp_fix로 했어요!
os.makedirs('./temp_fix')
os.chdir('./temp_fix')
os.getcwd()
# Out:
# '/usr/local/lib/python3.10/dist-packages/konlpy/java/temp_fix'

# %%
#inflated어쩌고 쭉뜨고 맨끝에 에러 없으면 잘된겁니다!
# !jar xvf ../open-korean-text-2.1.0.jar
# Out:
#   created: META-INF/
#  inflated: META-INF/MANIFEST.MF
#   created: org/
#   created: org/openkoreantext/
#   created: org/openkoreantext/processor/
#   created: org/openkoreantext/processor/normalizer/
#   created: org/openkoreantext/processor/phrase_extractor/
#   created: org/openkoreantext/processor/qa/
#   created: org/openkoreantext/processor/stemmer/
#   created: org/openkoreantext/processor/tokenizer/
#   created: org/openkoreantext/processor/tools/
#   created: org/openkoreantext/processor/util/
#   created: org/openkoreantext/processor/util/adjective/
#   created: org/openkoreantext/processor/util/adverb/
#   created: org/openkoreantext/processor/util/auxiliary/
#   created: org/openkoreantext/processor/util/freq/
#   created: org/openkoreantext/processor/util/josa/
#   created: org/openkoreantext/processor/util/noun/
#   created: org/openkoreantext/processor/util/substantives/
#   created: org/openkoreantext/processor/util/typos/
# ...

# %%
# 사용자 사전 열기
with open(f"/usr/local/lib/python3.10/dist-packages/konlpy/java/temp_fix/org/openkoreantext/processor/util/noun/names.txt") as f:
    data = f.read()
data
# Out:
# '가몽\n가온\n갓세븐\n강새이\n게임닉가\n관우\n귀여미\n규\n김유이\n김준면\n까까런\n노컷\n누너예\n니노\n다마고치\n다이무스\n대학생\n데이브\n도요토미\n동운\n동이\n두주니\n디시인사이드\n디오\n라몹\n라스\n라옵\n멍구\n메이든\n명덕\n명량\n문민정부\n미네\n방엘리\n병헌\n붓다\n비정상회담\n빼빼로\n삼풍\n샤인온미\n성식\n성열\n세라문\n세라복\n세종대왕\n손권\n손책\n쇼미더머니\n쇼챔\n순규\n스라소니\n신동아\n신쓰패밀리\n신아라\n아베\n안상홍\n안홍준\n여누\n여랑\n여포\n연합\n오꾸닭\n요섭\n웃찾사\n원식\n유병언\n유비\n유이\n윤기형\n이나단\n이명박\n이완용\n임창용\n자괴\n자니윤\n자대련\n자유\n재중이\n전교조\n정윤회\n제갈량\n조자룡\n조조\n준면\n지오디\n지존파\n진영오\n차작가\n차트\n창섭\n챠트\n첸\n코르사주\n하무열\n하용파쿠\n혁재\n현이\n현태\n혜미\n'

# %%
#데이터추가해주기_\n으로 이어줘야합니다
data +='경영대학원\n사회봉사센터\n학생상담센터\n외국어연수평가원\n공자아카데미\n다문화교육원\n원스톱서비스센터\n종합정보시스템\n학생지원팀\n외교통상연구센터\n학생복지위원회\n학복위원회\n'
data +='국제교류팀\nEU센터\nEU연구소\n글로벌캠퍼스\n서울캠퍼스\n행정지원처장\n국제학사\n국제학생지원팀\n정보통신팀\n정보지원처\n진로취업지원센터\n동남아연구소\n외국문학연구소\n국제학사\n'
data +='학교법인\n동원육영회\n학교법인동원육영회\n언어연구소\n러시아연구소\n학사운영팀\nFLEX센터\n학생지원장학팀\n인재개발처\n세계문화예술경영융합전공\n세계문화예술경영\n융합전공\n'
data +='영어대학\nELLT학과\n영미문학·문화학과\nEICC학과\n서양어대학\n프랑스어학부\n프랑스응용어문학전공\nFATI전공\n프랑스ㆍEU전공\n독일어과\n노어과\n스페인어과\n이탈리아어과\n'
data +='포르투갈어과\n네덜란드어과\n스칸디나비아어과\n아시아언어문화대학\n말레이ㆍ인도네시아어과\n아랍어과\n태국어과\n베트남어과\n인도어과\n터키ㆍ아제르바이잔어과\n이란어과\n몽골어과\n'
data +='중국어대학\n중국언어문화학부\n중국언어문화전공\n중국외교통상학부\n중국외교통상전공\n일본어대학\n일본언어문화학부\n일본언어문화전공\n융합일본지역학부\n융합일본지역전공\n'
data +='사회과학대학\n정치외교학과\n행정학과\n미디어커뮤니케이션학부\n언론ㆍ정보전공\n광고ㆍPRㆍ브랜딩전공\n방송ㆍ영상ㆍ뉴미디어전공\n상경대학\n국제통상학과\n경제학부\n경제학전공\n'
data +='경영대학\n경영학부\n경영학전공\n사범대학\n영어교육과\n프랑스어교육과\n독일어교육과\n한국어교육과\n중국어교육과\n국제학부\n국제학전공\nLanguage & Diplomacy학부\n'
data +='Language & Diplomacy전공\nLanguage & Trade학부\nLanguage & Trade전공\nKFL학부\n외국어로서의한국어교육전공\n외국어로서의한국어통번역전공\n인문대학\n인문과학계열\n철학과\n사학과\n'
data +='언어인지과학과\n지식콘텐츠학부\n지식콘텐츠전공\n통번역대학\n영어통번역학부\n영어통번역학전공\n영미권통상통번역전공\n영미문학ㆍ번역전공\nTESOL영어학전공\n독일어통번역학과\n'
data +='스페인어통번역학과\n이탈리아어통번역학과\n중국어통번역학과\n일본어통번역학과\n아랍어통번역학과\n말레이･인도네시아어통번역학과\n태국어통번역학과\n동유럽학대학\n폴란드어과\n'
data +='루마니아어과\n체코ㆍ슬로바키아어과\n헝가리어과\n세르비아ㆍ크로아티아어과\n우크라이나어과\n국제지역대학\n프랑스학과\n브라질학과\n그리스ㆍ불가리아학과\n인도학과\n중앙아시아학과\n'
data +='아프리카학부\n동아프리카어전공\n서아프리카어전공\n남아프리카어전공\n러시아학과\n국제스포츠레저학부\n국제스포츠레저전공\n한국학과\n경상대학\nGlobal Business & Technology학부\n'
data +='Global Business & Technology전공\n국제금융학과\n자연과학대학\n수학과\n통계학과\n전자물리학과\n환경학과\n생명공학과\n화학과\n공과대학\n컴퓨터·전자시스템공학부\n'
data +='컴퓨터·전자시스템공학전공\n정보통신공학과\n전자공학과\n산업경영공학과\n9바이오메디컬공학부\n바이오메디컬공학전공\n전략기획팀\n교수학습개발부\n교육선진화센터\n디지털서비스팀\n'
data +='비상대책위원회\n임용고시반\n시설관리팀\n글로벌정치연구소\n대학일자리본부\n서울평생교육원\n외국어교육센터\n지식출판원\n행정지원처장\n일반대학원\n통번역대학원\n국제지역대학원\n'
data +='경영대학원(주간)\n경영대학원(야간)\n교육대학원\n정치행정언론대학원\nTESOL대학원\n법학전문대학원\nKFL대학원\n한국외대학군단\n학군단\n전략홍보팀\n언론정보연구소\n사법연구실\n'
data +='모네EU센터\n외대교육방송국\n행정고시연구실\n역사문화연구소\n한국외대\n한국외국어대학교\n설명회\n세미오시스\n학년도\n인도연구소\n자기이해\n게시물\n한중\n외국문학연구소장\n'
data +='대외협력처\n발전협력팀\n국제교류처\n외국인유학생회\n지원서\n소속\n기관명\n상영회\n사이버관\n소강당\n정보기록학연구센터\n동대문구\n동대문구청\n모현읍\n외대로\n교양관\n콜로키움\n'
data +='한국장학재단\n1학기\n2학기\n2018학년도\n2018년도\n2018년\n2019학년도\n2019년\n2019년도\n2020학년도\n2020년도\n2020년\n2021학년도\n2021년도\n2021년\n2022학년도\n2022년도\n2022년\n'
data +='2023학년도\n2023년도\n2023년\n2024학년도\n2024년도\n2024년\n'

# 파일 새롭게 저장
with open("/usr/local/lib/python3.10/dist-packages/konlpy/java/temp_fix/org/openkoreantext/processor/util/noun/names.txt", 'w') as f:
    f.write(data)
data
# Out:
# '가몽\n가온\n갓세븐\n강새이\n게임닉가\n관우\n귀여미\n규\n김유이\n김준면\n까까런\n노컷\n누너예\n니노\n다마고치\n다이무스\n대학생\n데이브\n도요토미\n동운\n동이\n두주니\n디시인사이드\n디오\n라몹\n라스\n라옵\n멍구\n메이든\n명덕\n명량\n문민정부\n미네\n방엘리\n병헌\n붓다\n비정상회담\n빼빼로\n삼풍\n샤인온미\n성식\n성열\n세라문\n세라복\n세종대왕\n손권\n손책\n쇼미더머니\n쇼챔\n순규\n스라소니\n신동아\n신쓰패밀리\n신아라\n아베\n안상홍\n안홍준\n여누\n여랑\n여포\n연합\n오꾸닭\n요섭\n웃찾사\n원식\n유병언\n유비\n유이\n윤기형\n이나단\n이명박\n이완용\n임창용\n자괴\n자니윤\n자대련\n자유\n재중이\n전교조\n정윤회\n제갈량\n조자룡\n조조\n준면\n지오디\n지존파\n진영오\n차작가\n차트\n창섭\n챠트\n첸\n코르사주\n하무열\n하용파쿠\n혁재\n현이\n현태\n혜미\n경영대학원\n사회봉사센터\n학생상담센터\n외국어연수평가원\n공자아카데미\n다문화교육원\n원스톱서비스센터\n종합정보시스템\n학생지원팀\n외교통상연구센터\n학생복지위원회\n학복위원회\n국제교류팀\nEU센터\nEU연구소\n글로벌캠퍼스\n서울캠퍼스\n행정지원처장\n국제학사\n국제학생지원팀\n정보통신팀\n정보지원처\n진로취업지원센터\n동남아연구소\n외국문학연구소\n국제학사\n학교법인\n동원육영회\n학교법인동원육영회\n언어연구소\n러시아연구소\n학사운영팀\nFLEX센터\n학생지원장학팀\n인재개발처\n세계문화예술경영융합전공\n세계문화예술경영\n융합전공\n영어대학\nELLT학과\n영미문학·문화학과\nEICC학과\n서양어대학\n프랑스어학부\n프랑스응용어문학전공\nFATI전공\n프랑스ㆍEU전공\n독일어과\n노어과\n스페인어과\n이탈리아어과\n포르투갈어과\n네덜란드어과\n스칸디나비아어과\n아시아언어문화대학\n말레이ㆍ인도네시아어과\n아랍어과\n태국어과\n베트남어과\n인도어과\n터키ㆍ아제르바이잔어과\n이란어과\n몽골어과\n중국어대학\n중국언어문화학부\n중국언어
# ...

# %%
# 다시압축해주기. 마찬가지로 끝에 notfoundfile에러같은거 없으면 잘된겁니다!
# 안되면 pwd로 현재 경로가 temp_fix가 맞는지 확인해주세요
# !jar cvf ../open-korean-text-2.1.0.jar *
# Out:
# added manifest
# ignoring entry META-INF/
# adding: META-INF/maven/(in = 0) (out= 0)(stored 0%)
# adding: META-INF/maven/org.openkoreantext/(in = 0) (out= 0)(stored 0%)
# adding: META-INF/maven/org.openkoreantext/open-korean-text/(in = 0) (out= 0)(stored 0%)
# adding: META-INF/maven/org.openkoreantext/open-korean-text/pom.properties(in = 119) (out= 110)(deflated 7%)
# adding: META-INF/maven/org.openkoreantext/open-korean-text/pom.xml(in = 9127) (out= 2208)(deflated 75%)
# ignoring entry META-INF/MANIFEST.MF
# adding: org/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/normalizer/(in = 0) (out= 0)(stored 0%)
# adding: org/openkoreantext/processor/normalizer/KoreanNormalizer$Segment$.class(in = 2577) (out= 989)(deflated 61%)
# adding: org/openkoreantext/processor/normalizer/KoreanNormalizer.class(in = 2980) (out= 2181)(deflated 26%)
# ...

# %% [markdown]
# # 세션 다시 시작

# %% [markdown]
# # csv파일 불러오기

# %% [markdown]
# - 공지 3분할

# %%
# csv파일 읽어오기 - 공지 1/3
import pandas as pd
filename = "/content/drive/MyDrive/csv/gongji_1_of_3.csv"
gongji_1_of_3 = pd.read_csv(filename)

# 확인
gongji_1_of_3.head(3)
# Out:
#    index        date                                              title  \
# 0   4597  2024.03.27            [글로벌] 2024-1 명상 집단상담 ＇금모닝 마음챙김＇ 프로그램 안내
# 1   4596  2024.03.27  [서울] 보건실 - 심폐소생술 교육일정 안내 (2024.04.29(월) 10시 / ...
# 2   4595  2024.03.26               EU연구소 인문사회연구사업단, '제5회 바우하우스 콜로키움' 개최
#
#                                              content
# 0  \n글로벌 20241 명상 집단상담 금모닝 마음챙김 프로그램 안내\n\n학생상담센터...
# 1  \n심폐소생술 교육일정 안내\n\n서울캠퍼스 보건실에서는 교내 구성원의 응급처치 능...
# 2  \nEU연구소 인문사회연구사업단, 제5회 바우하우스 콜로키움 개최\n\n\nEU연구...

# %%
# csv파일 읽어오기 - 공지 2/3
import pandas as pd
filename = "/content/drive/MyDrive/csv/gongji_2_of_3.csv"
gongji_2_of_3 = pd.read_csv(filename)

# 확인
gongji_2_of_3.head(3)
# Out:
#    index        date                                    title  \
# 0   1960  2020.10.13           4차 산업혁명 시대 행정정보데이터세트 기록의 관리.활용
# 1   1959  2020.10.13  [글로벌] [20-2] English Zone 운영 및 전산예약제 안내
# 2   1958  2020.10.12              [서울] [서울]학생상담센터 2학기 프로그램 안내
#
#                                              content
# 0  \n4차 산업혁명 시대 행정정보데이터세트 기록의 관리.활용\n일  시 : 2020....
# 1  \n20202 English Zone 운영 및 전산예약제안내프로그램 소개 : 글로벌...
# 2  \n서울) 학생상담센터에서 2020년 2학기 프로그램을 안내합니다.학생분들의 많은 ...

# %%
# csv파일 읽어오기 - 공지 3/3
import pandas as pd
filename = "/content/drive/MyDrive/csv/gongji_3_of_3.csv"
gongji_3_of_3 = pd.read_csv(filename)

# 확인
gongji_3_of_3.head(3)
# Out:
#    index        date                                       title  \
# 0   2036  2020-11-04           [서울] 2020학년도 동계방학 국제학사 기숙사 입사생 모집
# 1   2035  2020-11-04             한국외대 언어연구소 2020 하반기 온라인 학술대회 안내
# 2   2034  2020-11-03  2020-2 Jump Start 프로그램(일대일 학습컨설팅) 3차 신청 안내
#
#                                              content
# 0  \n2020학년도 동계방학 국제학사 기숙사 입사생 모집      2020학년도 동계...
# 1  \n한국외대 언어연구소 2020 하반기 온라인 학술대회 안내\n한국외대 언어연구소에...
# 2                                              \n \n

# %% [markdown]
# - 공지 4분할

# %%
# csv파일 읽어오기 - 공지 1/4
import pandas as pd
filename = "/content/drive/MyDrive/csv/gongji_1_of_4.csv"
gongji_1_of_4 = pd.read_csv(filename)

# 확인
gongji_1_of_4.head(3)
# Out:
#    index        date                                              title  \
# 0   4597  2024.03.27            [글로벌] 2024-1 명상 집단상담 ＇금모닝 마음챙김＇ 프로그램 안내
# 1   4596  2024.03.27  [서울] 보건실 - 심폐소생술 교육일정 안내 (2024.04.29(월) 10시 / ...
# 2   4595  2024.03.26               EU연구소 인문사회연구사업단, '제5회 바우하우스 콜로키움' 개최
#
#                                              content
# 0  \n글로벌 20241 명상 집단상담 금모닝 마음챙김 프로그램 안내\n\n학생상담센터...
# 1  \n심폐소생술 교육일정 안내\n\n서울캠퍼스 보건실에서는 교내 구성원의 응급처치 능...
# 2  \nEU연구소 인문사회연구사업단, 제5회 바우하우스 콜로키움 개최\n\n\nEU연구...

# %%
# csv파일 읽어오기 - 공지 2/4
import pandas as pd
filename = "/content/drive/MyDrive/csv/gongji_2_of_4.csv"
gongji_2_of_4 = pd.read_csv(filename)

# 확인
gongji_2_of_4.head(3)
# Out:
#    index        date                              title  \
# 0   2776  2021.08.06        2022학년도 1학기 일본/중국어권 교류학생 모집
# 1   2773  2021.08.04         [서울] 보건실- 전문치료형 금연캠프 신청 안내
# 2   2770  2021.08.03  [대학혁신지원사업] 스크래치 코딩 프로젝트 참가자 모집 안내
#
#                                              content
# 0  \n2022학년도1학기 일본중국어권 교류학생 모집중요 공지:현재 전 세계적으로 코로...
# 1  \n서울금연지원센터 전문치료형 4박 5일 금연캠프 \n2021년도 89월 일정 안내...
# 2  \n교육혁신원에서는 방학 중 스크래치 코딩 프로젝트(비교과 프로그램)을 다음과 같이...

# %%
# csv파일 읽어오기 - 공지 3/4
import pandas as pd
filename = "/content/drive/MyDrive/csv/gongji_3_of_4.csv"
gongji_3_of_4 = pd.read_csv(filename)

# 확인
gongji_3_of_4.head(3)
# Out:
#    index        date                                             title  \
# 0    750  2019.01.21                         2018 동계 커리어 설정 워크숍 참가자 모집
# 1    749  2019.01.21  [공통] 2019년 상반기 인사혁신처 외국어위탁교육과정(주말14주) 반편성시험 시행안내
# 2    748  2019.01.17           6회 Better World 아이디어 공작소 개최 및 참가자 모집 안내
#
#                                              content
# 0  \n2018 동계 커리어 설정 워크숍 참가자 모집총 3회로 진행되며 각 회차별 프로...
# 1  \n2019년 상반기 인사혁신처 외국어위탁교육과정(주말14주) 반편성시험 시행안내\...
# 2  \n제 6회Better World 아이디어 공작소개최 및 참가자 모집 안내  교육선...

# %%
# csv파일 읽어오기 - 공지 4/4
import pandas as pd
filename = "/content/drive/MyDrive/csv/gongji_4_of_4.csv"
gongji_4_of_4 = pd.read_csv(filename)

# 확인
gongji_4_of_4.head(3)
# Out:
#    index        date                                              title  \
# 0   1193  2019-09-06                     [서울] 2019학년도 2학기 학생예비군 기본훈련 안내
# 1   1192  2019-09-06  [서울] [서울] 2019-2 외국어튜터링 (Foreign Language Peer...
# 2   1191  2019-09-05    [진로취업지원센터] 2019년 2학기 해외취업 현직자 특강(스웨덴, 일본) 개최 안내
#
#                                              content
# 0  \n(서울) 2019학년도 2학기 학생예비군 기본훈련 안내\n2019학년도 2학기 ...
# 1  \n20192 외국어튜터링 (Foreign Language Peer Tutoring...
# 2  \n진로취업지원센터 2019년 2학기 해외취업 현직자 특강(스웨덴, 일본) 개최 안...

# %% [markdown]
# - 공지 5분할

# %%
# csv파일 읽어오기 - 공지 1/5
import pandas as pd
filename = "/content/drive/MyDrive/csv/gongji_1_of_5.csv"
gongji_1_of_5 = pd.read_csv(filename)

# 확인
gongji_1_of_5.head(3)
# Out:
#    index        date                                              title  \
# 0   4597  2024.03.27            [글로벌] 2024-1 명상 집단상담 ＇금모닝 마음챙김＇ 프로그램 안내
# 1   4596  2024.03.27  [서울] 보건실 - 심폐소생술 교육일정 안내 (2024.04.29(월) 10시 / ...
# 2   4595  2024.03.26               EU연구소 인문사회연구사업단, '제5회 바우하우스 콜로키움' 개최
#
#                                              content
# 0  \n글로벌 20241 명상 집단상담 금모닝 마음챙김 프로그램 안내\n\n학생상담센터...
# 1  \n심폐소생술 교육일정 안내\n\n서울캠퍼스 보건실에서는 교내 구성원의 응급처치 능...
# 2  \nEU연구소 인문사회연구사업단, 제5회 바우하우스 콜로키움 개최\n\n\nEU연구...

# %%
# csv파일 읽어오기 - 공지 2/5
import pandas as pd
filename = "/content/drive/MyDrive/csv/gongji_2_of_5.csv"
gongji_2_of_5 = pd.read_csv(filename)

# 확인
gongji_2_of_5.head(3)
# Out:
#    index        date                                              title  \
# 0   3362  2022.03.11  2022-1 교수법 연구모임(FLC: Faculty Learning Communit...
# 1   3360  2022.03.10                       2022년 학군사관 후보생 63, 64기 모집 안내
# 2   3359  2022.03.10  한국유럽학회-한국외대 EU연구소 주관 ‘EU Youth Forum’     참가자 ...
#
#                                              content
# 0  \n교육혁신원에서는 교수법 연구모임(FLC: Faculty Learning Comm...
# 1  \n\n\nROTC 꿈과 열정이 넘치는 여러분을 기다립니다\n2022년 학군사관후보...
# 2  \n한국유럽학회한국외대 EU연구소 주관 EU Youth Forum     참가자 모...

# %%
# csv파일 읽어오기 - 공지 3/5
import pandas as pd
filename = "/content/drive/MyDrive/csv/gongji_3_of_5.csv"
gongji_3_of_5 = pd.read_csv(filename)

# 확인
gongji_3_of_5.head(3)
# Out:
#    index        date                                  title  \
# 0   1350  2019.11.21          2019년 한국외국어대학교 교육만족도 조사 참여 안내
# 1   1349  2019.11.20    HK 세미오시스 연구센터, 2019 해외저명인사 초청강연Ⅴ 개최
# 2   1348  2019.11.19  [공통] [외국어인증/외국어시험 대체] 겨울방학특별과정 교육생 모집
#
#                                              content
# 0  \n2019년 한국외국어대학교 교육만족도 조사 참여 안내\n학부 학생 여러분을 대상...
# 1  \nHK 세미오시스 연구센터, 2019 해외저명인사 초청강연Ⅴ 개최\n\n한국외대 ...
# 2  \n외국어인증외국어시험 대체 겨울방학특별과정 교육생 모집\n\n\n한국외국어대학교 ...

# %%
# csv파일 읽어오기 - 공지 4/5
import pandas as pd
filename = "/content/drive/MyDrive/csv/gongji_4_of_5.csv"
gongji_4_of_5 = pd.read_csv(filename)

# 확인
gongji_4_of_5.head(3)
# Out:
#    index        date                                   title  \
# 0    246  2018.05.04          한국외국어대학교 한중남미녹색융합센터 제9회 국내학술대회
# 1    245  2018.05.04  [진로취업] 국제협력세미나 개최 안내(국제기구 및 공공기관 취업전략)
# 2    244  2018.05.03          2018년 상반기 글로벌다국적기업 취업 특강 개최 안내
#
#                                              content
# 0  \n한국외국어대학교 한중남미녹색융합센터 제9회 국내학술대회 2018. 5한중남미녹색...
# 1  \n진로취업 국제협력세미나 개최 안내(국제기구 및 공공기관 취업전략)우리대학은 한국...
# 2  \n2018년 상반기 글로벌다국적기업 취업 특강 개최 안내\n우리대학은 대학일자리센...

# %%
# csv파일 읽어오기 - 공지 5/5
import pandas as pd
filename = "/content/drive/MyDrive/csv/gongji_5_of_5.csv"
gongji_5_of_5 = pd.read_csv(filename)

# 확인
gongji_5_of_5.head(3)
# Out:
#    index        date                              title  \
# 0    993  2019-05-20                      게시물이 이동되었습니다.
# 1    992  2019-05-20  [야간대학원]TESOL대학원 2019년 후기 입학설명회 안내
# 2    991  2019-05-17              <2019 책 나눔 한마당> 개최 안내
#
#                                              content
# 0  \n\n\n\n\n게시물이 이동되었습니다.기존게시판:대학생활_공지안내_공지 게시물번...
# 1  \n한국외국어대학교 TESOL대학원\n2019년 후기 입학설명회\n\nTESOL대학...
# 2  \n제9회 전국 대학(원)생 러시아어 토론대회\n책나눔\n한마당\n\n2019. 0...

# %% [markdown]
# - 학사, 장학, 채용

# %%
# csv파일 읽어오기 - 학사
import pandas as pd
filename = "/content/drive/MyDrive/csv/haksa.csv"
haksa = pd.read_csv(filename)

# 확인
haksa.head(3)
# Out:
#    index        date                                  title  \
# 0      1  2020-01-06         [공통] 2019-2학기 이중전공 변경 배정 확정 공고
# 1      2  2020-01-13               [공통] 2020학년도 1학기 수강신청 공고
# 2      3  2020-01-13  [공통] 2020학년도 전기 국제지역대학원 학석사연계과정 모집 안내
#
#                                              content
# 0  \n\n\n\n\n\n공통이중전공변경 배정 확정 공고\n \n2019학년도 제2학기...
# 1  \n2020학년도 1학기 수강신청 공고 2020학년도 제1학기 수강신청에 대하여 아...
# 2  \n2020학년도 전기 국제지역대학원 학석사연계과정 모집 안내\n \n2020학년도...

# %%
haksa.shape
# Out:
# (622, 4)

# %%
# csv파일 읽어오기 - 장학
import pandas as pd
filename = "/content/drive/MyDrive/csv/janghak.csv"
janghak = pd.read_csv(filename)

# 확인
janghak.head(3)
# Out:
#    index        date                                              title  \
# 0      1  2020-01-02          [공통][교외] 2020-1학기 남정장학재단 장학생 모집 안내(~1/10)
# 1      2  2020-01-02       [공통] [대출] 2020년 1학기 농촌출신대학생 학자금융자(무이자) 지원 안내
# 2      3  2020-01-07  [공통][교외] 2020년 상반기 시각장애대학생을 위한 [효명장학사업] 안내(~1/23)
#
#                                              content
# 0  \n공통교외 20201학기 남정장학재단 장학생 모집 안내(110)아래와 같이 202...
# 1  \n\n2020년 1학기 농촌출신대학생 학자금융자(무이자) 지원 안내\n\n \n사...
# 2  \n2020년 상반기 시각장애대학생을 위한 효명장학사업 안내 실로암시각장애인복지관에...

# %%
janghak.shape
# Out:
# (1260, 4)

# %%
# csv파일 읽어오기 - 채용
import pandas as pd
filename = "/content/drive/MyDrive/csv/hire.csv"
hire = pd.read_csv(filename)

# 확인
hire.head(3)
# Out:
#    index        date                   title  \
# 0   1269  2024.03.28      국제학사 공로봉사장학생 모집 안내
# 1   1268  2024.03.27  [사이버외대 영어학부] 전임조교 모집공지
# 2   1267  2024.03.27          중국연구소 전임연구원 모집
#
#                                              content
# 0  \n국제학사 사감 모집 공고(여 대학원생) \n\n1. 모집 관련 일반사항\n가. ...
# 1  \n사이버외대 영어학부 전임조교 모집공지\n\n사이버한국외국어대학교 영어학부에서는 ...
# 2  \n중국연구소 전임연구원 모집\n\n안녕하세요,한국외국어대학교 중국연구소입니다.\n...

# %% [markdown]
# # 영문, 빈 괄호 제거

# %%
# 영문(알파벳 대문자, 소문자)을 제거하는 함수
def remove_english(text):
    return re.sub(r'[a-zA-Z]', '', text)

# 빈 괄호를 제거하는 함수
def remove_empty_parentheses(text):
    return re.sub(r'\(\)', '', text)

# %% [markdown]
# - 장학

# %%
# index 1번째 글 후반부 'App'
janghak.head(2)
# Out:
#    index        date                                         title  \
# 0      1  2020-01-02     [공통][교외] 2020-1학기 남정장학재단 장학생 모집 안내(~1/10)
# 1      2  2020-01-02  [공통] [대출] 2020년 1학기 농촌출신대학생 학자금융자(무이자) 지원 안내
#
#                                              content
# 0  \n공통교외 20201학기 남정장학재단 장학생 모집 안내(110)아래와 같이 202...
# 1  \n\n2020년 1학기 농촌출신대학생 학자금융자(무이자) 지원 안내\n\n \n사...

# %%
# 영문 제거 함수 적용 - 장학
janghak['content'] = janghak['content'].apply(remove_english)

# %%
# App 제거됨
janghak.head(2)
# Out:
#    index        date                                         title  \
# 0      1  2020-01-02     [공통][교외] 2020-1학기 남정장학재단 장학생 모집 안내(~1/10)
# 1      2  2020-01-02  [공통] [대출] 2020년 1학기 농촌출신대학생 학자금융자(무이자) 지원 안내
#
#                                              content
# 0  \n공통교외 20201학기 남정장학재단 장학생 모집 안내(110)아래와 같이 202...
# 1  \n\n2020년 1학기 농촌출신대학생 학자금융자(무이자) 지원 안내\n\n \n사...

# %%
# 빈 괄호 제거 함수 적용 - 장학
janghak['content'] = janghak['content'].apply(remove_empty_parentheses)

# %%
# 빈 괄호 제거 확인
janghak.head(2)
# Out:
#    index        date                                         title  \
# 0      1  2020-01-02     [공통][교외] 2020-1학기 남정장학재단 장학생 모집 안내(~1/10)
# 1      2  2020-01-02  [공통] [대출] 2020년 1학기 농촌출신대학생 학자금융자(무이자) 지원 안내
#
#                                              content
# 0  \n공통교외 20201학기 남정장학재단 장학생 모집 안내(110)아래와 같이 202...
# 1  \n\n2020년 1학기 농촌출신대학생 학자금융자(무이자) 지원 안내\n\n \n사...

# %% [markdown]
# - 학사, 채용

# %%
# 영문 제거 함수 적용 - 학사
haksa['content'] = haksa['content'].apply(remove_english)

# 빈 괄호 제거 함수 적용
haksa['content'] = haksa['content'].apply(remove_empty_parentheses)

# %%
# 영문 제거 함수 적용 - 채용
hire['content'] = hire['content'].apply(remove_english)

# 빈 괄호 제거 함수 적용
hire['content'] = hire['content'].apply(remove_empty_parentheses)

# %% [markdown]
# - 공지

# %%
# 영문 제거 함수 적용 - 공지 1/5
gongji_1_of_5['content'] = gongji_1_of_5['content'].apply(remove_english)

# 빈 괄호 제거 함수 적용
gongji_1_of_5['content'] = gongji_1_of_5['content'].apply(remove_empty_parentheses)

# %%
# 영문 제거 함수 적용 - 공지 2/5
gongji_2_of_5['content'] = gongji_2_of_5['content'].apply(remove_english)

# 빈 괄호 제거 함수 적용
gongji_2_of_5['content'] = gongji_2_of_5['content'].apply(remove_empty_parentheses)

# %%
# 영문 제거 함수 적용 - 공지 3/5
gongji_3_of_5['content'] = gongji_3_of_5['content'].apply(remove_english)

# 빈 괄호 제거 함수 적용
gongji_3_of_5['content'] = gongji_3_of_5['content'].apply(remove_empty_parentheses)

# %%
# 영문 제거 함수 적용 - 공지 4/5
gongji_4_of_5['content'] = gongji_4_of_5['content'].apply(remove_english)

# 빈 괄호 제거 함수 적용
gongji_4_of_5['content'] = gongji_4_of_5['content'].apply(remove_empty_parentheses)

# %%
# 영문 제거 함수 적용 - 공지 5/5
gongji_5_of_5['content'] = gongji_5_of_5['content'].apply(remove_english)

# 빈 괄호 제거 함수 적용
gongji_5_of_5['content'] = gongji_5_of_5['content'].apply(remove_empty_parentheses)

# %% [markdown]
# # csv파일 저장

# %% [markdown]
# # Komoran

# %%
# konlpy 설치
# !pip install konlpy

# %%
from konlpy.tag import Komoran

# 초기화
komoran = Komoran()

# 명사, 동사, 형용사, 어간의 품사만 반환하는 함수
def komoran_tokenize(sent):
    words = komoran.pos(sent, join=True)
    words = [w for w in words if ('/NN' in w or '/XR' in w or '/VA' in w or '/VV' in w)]
    return words

# %% [markdown]
# # textrank

# %%
# 패키지 인스톨
# !pip install git+https://github.com/lovit/textrank.git
# Out:
# ...
#   Cloning https://github.com/lovit/textrank.git to /tmp/pip-req-build-9yzuzhxh
#   Running command git clone --filter=blob:none --quiet https://github.com/lovit/textrank.git /tmp/pip-req-build-9yzuzhxh
#   Resolved https://github.com/lovit/textrank.git to commit 578c7fbbb22b24561b1bd4bab9a9ecc2dc9515e1
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for textrank: filename=textrank-0.1.2-py3-none-any.whl size=11142 sha256=5a432f7e0314b3d33a0771eb536f80e58d5533dc2a139acb2c55d9b2f5fc7714
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2tc367yv/wheels/8d/d1/ef/7c6abc0d5bbb64f01bd86b0ad967911d4b7f21bb44813b3239
# Successfully built textrank
# ...

# %%
# 깃 클론
# !git clone https://github.com/lovit/textrank.git
# Out:
# Cloning into 'textrank'...
# remote: Enumerating objects: 232, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 232 (delta 1), reused 1 (delta 0), pack-reused 225
# Receiving objects: 100% (232/232), 1.21 MiB | 14.12 MiB/s, done.
# Resolving deltas: 100% (133/133), done.

# %%
# 해당 디렉토리로 이동
# %cd textrank
# Out:
# /content/textrank

# %%
# 이제 리포지토리의 코드를 사용할 수 있습니다.
from textrank import KeywordSummarizer, KeysentenceSummarizer

# 예시 코드
def example_tokenize(sentence):
    return sentence.split()

# %% [markdown]
# # df의 content를 리스트에 넣어 문장 분리

# %%
# 'gongji_1_of_3' 첫 번째 행 'content' 추출
str1 = gongji_1_of_3.loc[0, 'content']
print(str1)
# Out:
# 글로벌 20241 명상 집단상담 금모닝 마음챙김 프로그램 안내
#
# 학생상담센터에서는 다가오는 4월 5일,
# 명상에 대해 배워보고 체험해볼 수 있는 금모닝 마음챙김 집단상담이 열립니다
# 명상과 마음챙김에 관심있는 학생 분들의 많은 참여 부탁드립니다
# (식목일을 맞아, 실시 후만족도조사에 참여해주신 모든 분들께 다육이 화분을 선물로 드려요)
#
#
#
# 일 시 : 2024.04.05.(금)10:0010:50 (A time) 또는11:0011:50 (B time), 택 1
#
# 대 상 :명상에 대해 관심있는 글로벌 캠퍼스 재학생이라면 누구나 (회차별 선착순 10명)
#
# 장 소 :추후 공지 예정 (대면)
#
# 참여방법 :HUFSAbility 신청 (QR 코드) , 선착순 마감
#
# 문 의:학생상담센터()
#
#
# 2024학년도 1학기 명상 집단상담
# 금모닝 마음챙김
# 긴장되거나 불안할 때, 스트레스가 심할 때, 주의집중이 필요할 때, 활용해볼 수 있는 명상을 전문가와 함께 배우고 직접 체험해보는 시간
#
# 일시
# 2024.04.05. 10:0010:50 (A time)
# 2024.04.05.(금) 11:0011:50 (B time) 택 1
#
# 대상
# 명상에 대해 관심있는 글로벌 캠퍼스 재학생이라면 누구나 (회차별 선착순 10명)
#
# 장소
# 추후 공지 예정(대면)
# 참여방법 HUFSAbility 신청 (QR 코드), 선착순 마감
#
# 참여후 만족도조사에 참여한 분들께는 식목일을 맞아 힐링다육이화분을 선물로 드립니다
# 문의 : 학생상담센터

# %%
# 'janghak' 첫 번째 행 'content' 추출
str2 = janghak.loc[0, 'content']
print(str2)
print()
# Out:
# 공통교외 20201학기 남정장학재단 장학생 모집 안내(110)아래와 같이 20201학기 남정장학재단 신규장학생 모집 안내를 하니 관심있는 학생들의 많은 지원 바랍니다. 아 래 1. 재단명: 남정장학재단2. 장학금액: 1학기 당 250만원(지원자격 충족시 8학기 까지)3. 지원자격가. 20201학기 재학생(8학기 이내)나. 직전 학기 및 전체평점 3.54.5 이상인 학생다. 등록금 범위 내 지급 가능한 장학금임(부모의 회사에서 지급하는 자녀 학자금을 받고 있는 자는 지원 불가)( 선발 분아 : 인문. 사회계열)4. 제출서류가. 장학생 신청서(붙임파일 참조, 남정장학재단 홈페이지 다운로드 가능)나. 장학생 추천서(붙임파일 참조, 남정장학재단 홈페이지 다운로드 가능, 추천소견 및 총장 직인공란으로 두고본인 작성 부분만 작성 후 제출)다. 성적증명서(20192학기 성적 포함, 1월 7일 이후 발급 시 2학기 성적 반영)라. 자기소개서: 전공분야 학습계획과 졸업 후 진로계획을 중심으로 작성(자유양식, A4 2 페이지 이내)마. 주민등록등본(개인정보보호 위하여 뒷자리  표시, 부모님과 거주지가 다른 경우 본인 및 부모님 각 1통 씩)5. 가계 곤란 증명서류가. 기초생활 수급권자: 수급자 증명서나. 차상위 계층으로 모자가정부자가정: 주민센터 발행 한부모가정 증명서다. 가. 나에 해당되지 않는 자는 다음의 서류 모두 준비 바랍니다.1) 재산세 납세증명서(2018, 2019년) : 지방세 세목별 과세증명서 부, 모 각 1통(납부분 없을 경우, 납부분 없음 기재하여 발급 요청)2) 건강보험료 납부확인서(2018, 2019년) : 부, 모 각 1통(한 분만 납부하실 경우, 건강보험증 사본 또는 건강보험 자격확인서 함께 제출 요망)3) 소득세관련서류가) 소득세 과세자 중 급여 생활자의 경우: 근로소득 원천징수 영수증 부,모 각 1통(근무처 발행)나) 소득세 과세자 중 자영업자 등의 경우: 소득금액증명원 부,모 각 1통(세무서 발행)다) 소득세 미과세 자인 경우: 비사업자 사실증
# ...

# %%
# 'haksa' 첫 번째 행 'content' 추출
str3 = haksa.loc[0, 'content']
print(str3)
print()
# Out:
# 공통이중전공변경 배정 확정 공고
#
# 2019학년도 제2학기 이중전공 변경 배정 결과를 아래와 같이 공고함.
#
# 아 래
#
# 1. 결과조회 : 종합정보시스템  전공교직관리  이중전공 변경신청  안내사항
#
# 2. 이중전공 변경 시에 배정된 학생은 추후 이중전공 변경 신청 불가
#  미배정된 학생은 기존 이수중인 이중전공부전공이 유지되며, 추후 이중전공 변경 기간 중 신청 가능
#
# 3. 2020년 2월 졸업예정자(4학년 수료_졸업대기 포함)는 반드시 1월초까지 이수구분변경신청을 하여
#  영역별 졸업 학점에 누락 되는 일이 없도록 해야 함
#
# 4. 이중전공 변경에 따라 성적 조회 후, 변경되지 않은 이수구분의 수정은 학사종합지원센터 내
#  1전공 소속 단과대학 창구에 방문하여 이수구분변경신청원을 작성하여 제출 하여야 함(방학 및 학기 중 가능)
#
# 5. 기타사항
# (1) 부전공, 전공심화부전공, 단일전공(기존 이중전공부전공 취소) 신청기간
#  2020.1.291.31 종합정보시스템에서 신청(1월 중순 학사공지 참조 바람)
# (2) 다음 학기 이중전공 변경기간은 5월초로 예정되어 있음.
#
# 2020. 1
#
# 교무처장

# %%
# 'hire' 첫 번째 행 'content' 추출
str4 = hire.loc[30, 'content']
print(str4)
print()
# Out:
# TESOL대학원 (야간)근로장학생 모집 공고
#
# TESOL대학원 교학처에서 근무할(야간)근로장학생 아래와 같이 모집합니다.
# 교학처 행정 업무를 위해 함께할 인재분들의 관심과 지원 부탁드립니다.
#
#  아 래
#
# 1.모집인원: 1명
#
# 2.지원자격 가.교내 대학원생
# 나.타 장학금 미수혜자
# 다.엑셀 및 한글 문서 작성 등 컴퓨터 활용이 가능한 자
#
# 3.전형방법:서류전형 및 면접전형
#  서류 제출자에 개별 연락하여 면접 일정 논의 예정
#
# 4.근무기간: (수습,인수인계 기간) 2024.02.26.  02.29.
# (정식근무기간) 2024.03.04.  2024.06.21(학기 중)
#
# 5.근무조건
# 가.급여 : 기본급  시급(9,860원)
# 나.근무시간 : 월요일금요일 18:0022:00 중 상세 근무 시간 협의 예정
#
# 6.제출서류:이력서(사진첨부) 1부 (첨부파일의 이력서 양식 사용)
#
# 7.제 출 처
# 가.제출방법:이메일()로 접수 또는방문접수(대학원건물1층 111호 대학원사무2팀)
# 나.제출기한: 2024. 2. 23(금)까지
# 다.문 의:
#
# 한국외국어대학교TESOL대학원

# %%
# 줄바꿈을 기준으로 문자열 분리하여 리스트에 저장
sents = str4.split('\n')
print(type(sents), sents)
# Out:
# <class 'list'> ['', 'TESOL대학원 (야간)근로장학생 모집 공고', '', 'TESOL대학원 교학처에서 근무할(야간)근로장학생 아래와 같이 모집합니다.', '교학처 행정 업무를 위해 함께할 인재분들의 관심과 지원 부탁드립니다.', '', ' 아 래 ', '', '1.모집인원: 1명', '', '2.지원자격 가.교내 대학원생', '나.타 장학금 미수혜자', '다.엑셀 및 한글 문서 작성 등 컴퓨터 활용이 가능한 자', '', '3.전형방법:서류전형 및 면접전형', ' 서류 제출자에 개별 연락하여 면접 일정 논의 예정', '', '4.근무기간: (수습,인수인계 기간) 2024.02.26.  02.29.', '(정식근무기간) 2024.03.04.  2024.06.21(학기 중)', '', '5.근무조건', '가.급여 : 기본급  시급(9,860원)', '나.근무시간 : 월요일금요일 18:0022:00 중 상세 근무 시간 협의 예정', '', '6.제출서류:이력서(사진첨부) 1부 (첨부파일의 이력서 양식 사용)', '', '7.제 출 처', '가.제출방법:이메일()로 접수 또는방문접수(대학원건물1층 111호 대학원사무2팀)', '나.제출기한: 2024. 2. 23(금)까지', '다.문 의: ', '', '한국외국어대학교TESOL대학원', '']

# %%
# 빈 문자열 제거
sents = list(filter(None, sents))
print(sents)
# Out:
# ['TESOL대학원 (야간)근로장학생 모집 공고', 'TESOL대학원 교학처에서 근무할(야간)근로장학생 아래와 같이 모집합니다.', '교학처 행정 업무를 위해 함께할 인재분들의 관심과 지원 부탁드립니다.', ' 아 래 ', '1.모집인원: 1명', '2.지원자격 가.교내 대학원생', '나.타 장학금 미수혜자', '다.엑셀 및 한글 문서 작성 등 컴퓨터 활용이 가능한 자', '3.전형방법:서류전형 및 면접전형', ' 서류 제출자에 개별 연락하여 면접 일정 논의 예정', '4.근무기간: (수습,인수인계 기간) 2024.02.26.  02.29.', '(정식근무기간) 2024.03.04.  2024.06.21(학기 중)', '5.근무조건', '가.급여 : 기본급  시급(9,860원)', '나.근무시간 : 월요일금요일 18:0022:00 중 상세 근무 시간 협의 예정', '6.제출서류:이력서(사진첨부) 1부 (첨부파일의 이력서 양식 사용)', '7.제 출 처', '가.제출방법:이메일()로 접수 또는방문접수(대학원건물1층 111호 대학원사무2팀)', '나.제출기한: 2024. 2. 23(금)까지', '다.문 의: ', '한국외국어대학교TESOL대학원']

# %%
sents.append('-')
sents.append('-')
print(sents)
# Out:
# ['TESOL대학원 (야간)근로장학생 모집 공고', 'TESOL대학원 교학처에서 근무할(야간)근로장학생 아래와 같이 모집합니다.', '교학처 행정 업무를 위해 함께할 인재분들의 관심과 지원 부탁드립니다.', ' 아 래 ', '1.모집인원: 1명', '2.지원자격 가.교내 대학원생', '나.타 장학금 미수혜자', '다.엑셀 및 한글 문서 작성 등 컴퓨터 활용이 가능한 자', '3.전형방법:서류전형 및 면접전형', ' 서류 제출자에 개별 연락하여 면접 일정 논의 예정', '4.근무기간: (수습,인수인계 기간) 2024.02.26.  02.29.', '(정식근무기간) 2024.03.04.  2024.06.21(학기 중)', '5.근무조건', '가.급여 : 기본급  시급(9,860원)', '나.근무시간 : 월요일금요일 18:0022:00 중 상세 근무 시간 협의 예정', '6.제출서류:이력서(사진첨부) 1부 (첨부파일의 이력서 양식 사용)', '7.제 출 처', '가.제출방법:이메일()로 접수 또는방문접수(대학원건물1층 111호 대학원사무2팀)', '나.제출기한: 2024. 2. 23(금)까지', '다.문 의: ', '한국외국어대학교TESOL대학원', '-', '-']

# %%
# 공백만 있는 문자열 제거
sents = [sent for sent in sents if sent.strip()]
print(sents)
# Out:
# ['TESOL대학원 (야간)근로장학생 모집 공고', 'TESOL대학원 교학처에서 근무할(야간)근로장학생 아래와 같이 모집합니다.', '교학처 행정 업무를 위해 함께할 인재분들의 관심과 지원 부탁드립니다.', ' 아 래 ', '1.모집인원: 1명', '2.지원자격 가.교내 대학원생', '나.타 장학금 미수혜자', '다.엑셀 및 한글 문서 작성 등 컴퓨터 활용이 가능한 자', '3.전형방법:서류전형 및 면접전형', ' 서류 제출자에 개별 연락하여 면접 일정 논의 예정', '4.근무기간: (수습,인수인계 기간) 2024.02.26.  02.29.', '(정식근무기간) 2024.03.04.  2024.06.21(학기 중)', '5.근무조건', '가.급여 : 기본급  시급(9,860원)', '나.근무시간 : 월요일금요일 18:0022:00 중 상세 근무 시간 협의 예정', '6.제출서류:이력서(사진첨부) 1부 (첨부파일의 이력서 양식 사용)', '7.제 출 처', '가.제출방법:이메일()로 접수 또는방문접수(대학원건물1층 111호 대학원사무2팀)', '나.제출기한: 2024. 2. 23(금)까지', '다.문 의: ', '한국외국어대학교TESOL대학원', '-', '-']

# %%
# 키워드 요약----------------------


# KeywordSummarizer 인스턴스 생성
summarizer = KeywordSummarizer(tokenize=example_tokenize, verbose=True)

# 키워드 요약 실행
keywords = summarizer.summarize(sents)

# 출력
print(keywords)
# Out:
# word cooccurrence counting from 23 sents was done
# trained TextRank. n words = 5
# [(':', 1.0), ('예정', 1.0), ('-', 0.15000000000000002), ('및', 0.15000000000000002), ('TESOL대학원', 0.15000000000000002)]

# %%
# 문장 요약-----------------------


# KeywordSummarizer 인스턴스 생성
summarizer = KeysentenceSummarizer(tokenize = komoran_tokenize, min_sim = 0.3)

# 핵심 3문장 요약 실행
keysents = summarizer.summarize(sents, topk=3)

# 출력
print(keysents)
# Out:
# [(1, 1.4047636020713608, 'TESOL대학원 교학처에서 근무할(야간)근로장학생 아래와 같이 모집합니다.'), (9, 1.118607377195501, ' 서류 제출자에 개별 연락하여 면접 일정 논의 예정'), (11, 1.0733847300185957, '(정식근무기간) 2024.03.04.  2024.06.21(학기 중)')]

# %%
# 문장만 출력
print(keysents[2][2])
print(keysents[1][2])
print(keysents[0][2])
# Out:
# (정식근무기간) 2024.03.04.  2024.06.21(학기 중)
#  서류 제출자에 개별 연락하여 면접 일정 논의 예정
# TESOL대학원 교학처에서 근무할(야간)근로장학생 아래와 같이 모집합니다.

# %% [markdown]
# # Okt

# %%
from konlpy.tag import Okt

okt = Okt()

def okt_tokenize(sent):
    words = okt.pos(sent, join=True)
    words = [w for w in words if ('/Noun' in w or '/Adjective' in w or '/Verb' in w)]
    return words

# %%
# 문장 요약-----------------------


# KeywordSummarizer 인스턴스 생성
summarizer = KeysentenceSummarizer(tokenize = okt_tokenize, min_sim = 0.3)

# 핵심 3문장 요약 실행
keysents = summarizer.summarize(sents, topk=3)

# 출력
print(keysents)
# Out:
# [(1, 1.4004321361960619, 'TESOL대학원 교학처에서 근무할(야간)근로장학생 아래와 같이 모집합니다.'), (9, 1.2513847511632332, ' 서류 제출자에 개별 연락하여 면접 일정 논의 예정'), (14, 1.0851885560231598, '나.근무시간 : 월요일금요일 18:0022:00 중 상세 근무 시간 협의 예정')]

# %%
# 문장만 출력
print(keysents[0][2])
print(keysents[1][2])
print(keysents[2][2])
# Out:
# TESOL대학원 교학처에서 근무할(야간)근로장학생 아래와 같이 모집합니다.
#  서류 제출자에 개별 연락하여 면접 일정 논의 예정
# 나.근무시간 : 월요일금요일 18:0022:00 중 상세 근무 시간 협의 예정

# %% [markdown]
# # komoran_key_sents

# %%
import re

# %%
from konlpy.tag import Komoran

# 초기화
komoran = Komoran()

# 명사, 동사, 형용사, 어간의 품사만 반환하는 함수
def komoran_tokenize(sent):
    words = komoran.pos(sent, join=True)
    words = [w for w in words if ('/NN' in w or '/XR' in w or '/VA' in w or '/VV' in w)]
    return words

# %%
def komoran_key_sents(df, row):
  # df 데이터프레임의 row번째 행의 content를 문자열로 저장
  cont = df.loc[row, 'content']

  # 줄바꿈을 기준으로 문자열 분리하여 리스트에 저장
  sents = cont.split('\n')

  # 빈 문자열 제거
  sents = list(filter(None, sents))

  # 공백만 있는 문자열 제거
  sents = [sent for sent in sents if sent.strip()]

  # KeywordSummarizer 인스턴스 생성
  summarizer = KeysentenceSummarizer(tokenize = komoran_tokenize, min_sim = 0.3)

  # 핵심 3문장 요약 실행
  keysents = summarizer.summarize(sents, topk=3)

  # 반환
  return keysents[0][2], keysents[1][2], keysents[2][2]

# %%
komoran_key_sents(haksa, 0)
# Out:
# (' 미배정된 학생은 기존 이수중인 이중전공부전공이 유지되며, 추후 이중전공 변경 기간 중 신청 가능',
#  '4. 이중전공 변경에 따라 성적 조회 후, 변경되지 않은 이수구분의 수정은 학사종합지원센터 내 ',
#  '2019학년도 제2학기 이중전공 변경 배정 결과를 아래와 같이 공고함.')

# %% [markdown]
# # Okt_key_sents

# %%
import re

# %%
def okt_key_sents(df, row):
  # content가 빈 문자열이면 빈 리스트를 반환
  if df.loc[row, 'content'] == '':
      return []

  # df 데이터프레임의 row번째 행의 content를 문자열로 저장
  cont = df.loc[row, 'content']

  # 줄바꿈, 온점(.)을 기준으로 문자열 분리하여 리스트에 저장
  sents = re.split(r'[.\n]+', cont)

  # 3줄 미만 공지에 대비하여 추가
  sents.append('-')
  sents.append('-')
  sents.append('-')

  # 빈 문자열 제거
  sents = list(filter(None, sents))

  # 공백만 있는 문자열 제거
  sents = [sent for sent in sents if sent.strip()]

  # KeywordSummarizer 인스턴스 생성
  summarizer = KeysentenceSummarizer(tokenize = okt_tokenize, min_sim = 0.3)

  # 핵심 3문장 요약 실행
  keysents = summarizer.summarize(sents, topk=3)

  # 반환
  return keysents[0][2], keysents[1][2], keysents[2][2]

# %% [markdown]
# # 함수 사용

# %%
# 'haksa' 첫 번째 행 'content' 추출
str3 = haksa.loc[1, 'content']
print(str3)
# Out:
# 2020학년도 1학기 수강신청 공고 2020학년도 제1학기 수강신청에 대하여 아래와 같이 공고합니다. 아  래 1. 강의시간표강의계획서 조회 및 수강편람 열람 가. 강의시간표 및 강의계획서 조회 : 학교 홈페이지  Hot Link 강의시간표 조회 변동사항이 실시간으로 반영되므로, 수강신청 전 다시 확인바람.나. 수강편람 열람 : 학교 홈페이지  Hot Link 수강편람 수강편람은 매 학기 수강신청 전 학교 홈페이지 Hot Link에 게시 (1월말 예정)2. 수강신청 일정 ( 20192학기부터 장바구니 명칭 변경  예비수강신청함)구 분일 정비 고예비수강신청함(구)장바구니2020. 1. 29(수) 10:00  수강신청 변경 종료시까지학교홈페이지 : .krHot Link 수강신청예비수강신청함바로가기수강신청재학생4학년2020. 2. 3(월) 10:00  15:003학년2020. 2. 4(화) 10:00  15:002학년2020. 2. 5(수) 10:00  15:001학년2020. 2. 6(목) 10:00  15:00전체 학년2020. 2. 7(금) 10:00  15:00신편입생2020. 3. 9(월) 10:00  16:00수강신청 변경2020. 3. 16(월)  3. 20(금) 매일 10:00  16:00  가. 본인의 1전공 학년 기준 수강일자에 1전공 및 이중(부)전공 수강신청나. 수강신청학년 : 수강신청 전 예비수강신청함에 로그인하여 필히 사전 확인 20201학기 등록횟수 기준4학년(등록 7회 이상), 3학년(등록 56회),2학년(등록 34회), 1학년(등록 12회)다. 기타안내신편입생 및 외국인 교환학생, 외국인 방문학생 입학한 첫 학기 재수강 신청 불가 20201학기 복학예정자복학 신청 전 수강신청 기간에 수강신청 가능20201학기 휴학신청자수강신청 전 휴학신청수강신청 로그인 불가수강신청 후 휴학신청휴학 승인 시 수강신청 과목 일괄 삭제됨.라. 수강신청 기간2020. 2. 3(월)  2. 7(금) 종료 후 수강인원 0명 강좌 자동 폐강(전공 2학년 이상 
# ...

# %%
okt_key_sents(haksa, 1)
# Out:
# <class 'str'>
# ...

# %% [markdown]
# # 반복문 적용

# %%
okt_key_sents(haksa, 1)
# Out:
# (' 수강신청 관련 FAQ질문답변제한인원 증원 여부전공각 학과에서 증원여부 결정 및 시스템 증원 처리 해당학과 문의(서울캠퍼스)(클릭), (글로벌캠퍼스)(클릭)교양증원 불가온라인으로 수강신청하지 못한 과목을 교수님께 허락(사인)받아 수강할 수 있는지 여부불가 모든 과목은 수강신청 및 변경기간에 학생 본인이 온라인으로 수강신청을 완료하여야 합니다',
#  ' 31(화) 매일 10:0022:00방법학교 홈페이지    수강신청취소 바로가기에서 신청 수강신청 취소 후 본인의 강의시간표 반드시 확인(1) 12학점 미만으로 취소 불가(단, 4학년은 예외이나 전체 과목을 취소할 수는 없음)(2) 수강신청은 12학점 미만으로 가능하나, 이 경우 수강 취소 불가9',
#  ' 수강신청 방법방 법내 용예비수강신청함 활용 학교 홈페이지  Hot Link 예비수강신청함 바로가기로 로그인 수강희망과목을 선택하여 예비수강신청함에 담기(최대 15강좌) 수강신청기간에 예비수강신청함 목록에서 수강할 과목을 선택하여 수강신청과목별 조회신청 학교 홈페이지  Hot Link 수강신청 또는 수강신청 변경 바로가기로 로그인 전공, 이중(부)전공, 교양 등 영역별로 개설 과목을 조회하여 한 과목씩 수강신청 과목조회 신청은 수강신청(변경)기간 중에만 이용할 수 있음')

# %%
# 결과를 저장할 새로운 열 생성
haksa['result'] = None

# %%
# 반복문을 사용하여 각 행에 대해 okt_key_sents 함수를 적용 - 장학: 33 -> 33
error = 0
for i in range(len(janghak)):
    try:
        okt_key_sents(janghak, i)
    except Exception as e:
        print(f"오류 발생: {e} - 인덱스: {i}")
        error += 1
        continue
print(f'총 오류 수 : {error}')
# Out:
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 101
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 102
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 106
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 107
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 109
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 112
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 118
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 129
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 130
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 140
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 152
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 154
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 159
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 164
# ...

# %%
# 반복문을 사용하여 각 행에 대해 okt_key_sents 함수를 적용 - 학사: 4 -> 4
error = 0
for i in range(len(haksa)):
    try:
        okt_key_sents(haksa, i)
    except Exception as e:
        print(f"오류 발생: {e} - 인덱스: {i}")
        error += 1
        continue
print(f'총 오류 수 : {error}')
# Out:
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 107
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 115
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 133
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 187
# 총 오류 수 : 4

# %%
# 반복문을 사용하여 각 행에 대해 okt_key_sents 함수를 적용 - 채용: 16 -> 16
error = 0
for i in range(len(hire)):
    try:
        okt_key_sents(hire, i)
    except Exception as e:
        print(f"오류 발생: {e} - 인덱스: {i}")
        error += 1
        continue
print(f'총 오류 수 : {error}')
# Out:
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 137
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 154
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 312
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 457
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 538
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 556
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 598
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 774
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 791
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 908
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 1047
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 1048
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 1055
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 1072
# ...

# %%
# 반복문을 사용하여 각 행에 대해 okt_key_sents 함수를 적용 - 공지 1/5
error = 0
for i in range(len(gongji_1_of_5)):
    try:
        okt_key_sents(gongji_1_of_5, i)
    except Exception as e:
        print(f"오류 발생: {e} - 인덱스: {i}")
        error += 1
        continue
print(f'총 오류 수 : {error}')
# Out:
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 129
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 173
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 208
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 413
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 530
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 717
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 779
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 811
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 846
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 866
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 905
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 924
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 936
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 950
# ...

# %%
# 반복문을 사용하여 각 행에 대해 okt_key_sents 함수를 적용 - 공지 2/5
error = 0
for i in range(len(gongji_2_of_5)):
    try:
        okt_key_sents(gongji_2_of_5, i)
    except Exception as e:
        print(f"오류 발생: {e} - 인덱스: {i}")
        error += 1
        continue
print(f'총 오류 수 : {error}')
# Out:
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 39
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 93
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 119
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 122
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 220
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 231
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 240
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 282
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 317
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 326
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 353
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 357
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 435
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 451
# ...

# %%
# 반복문을 사용하여 각 행에 대해 okt_key_sents 함수를 적용 - 공지 3/5
error = 0
for i in range(len(gongji_3_of_5)):
    try:
        okt_key_sents(gongji_3_of_5, i)
    except Exception as e:
        print(f"오류 발생: {e} - 인덱스: {i}")
        error += 1
        continue
print(f'총 오류 수 : {error}')
# Out:
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 6
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 7
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 10
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 11
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 32
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 33
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 40
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 45
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 49
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 65
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 75
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 78
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 83
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 84
# ...

# %%
# 반복문을 사용하여 각 행에 대해 okt_key_sents 함수를 적용 - 공지 4/5
error = 0
for i in range(len(gongji_4_of_5)):
    try:
        okt_key_sents(gongji_4_of_5, i)
    except Exception as e:
        print(f"오류 발생: {e} - 인덱스: {i}")
        error += 1
        continue
print(f'총 오류 수 : {error}')
# Out:
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 8
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 26
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 43
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 45
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 57
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 70
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 76
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 80
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 87
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 93
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 152
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 166
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 178
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 183
# ...

# %%
# 반복문을 사용하여 각 행에 대해 okt_key_sents 함수를 적용 - 공지 5/5
error = 0
for i in range(len(gongji_5_of_5)):
    try:
        okt_key_sents(gongji_5_of_5, i)
    except Exception as e:
        print(f"오류 발생: {e} - 인덱스: {i}")
        error += 1
        continue
print(f'총 오류 수 : {error}')
# Out:
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 17
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 25
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 75
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 91
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 130
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 271
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 273
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 290
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 294
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 313
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 362
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 368
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 382
# 오류 발생: object dtype is not supported by sparse matrices - 인덱스: 390
# ...
